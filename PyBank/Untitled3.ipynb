# %% [markdown]
# split

# %%
# Initialize the metric variables:
    
number_of_months = 0
    
net_profit_loss = 0
    
change_in_profits = 0
    
total_change_in_profits_for_the_period = 0
    
average_change_in_profit_for_the_period = 0
    
greatest_increase_in_profits = 0
    
greatest_increase_in_profits_date = " "
    
greatest_decrease_in_losses = 0
    
greatest_decrease_in_losses_date = " "
    
    
# Calculate all of the variables above:
counter = 0

# (List length = 86)
while counter < len(budgets):
    
    
    # Add up all of the months
    number_of_months =+ 1
    
    # Add up the total profits and losses
    net_profit_losses =+ budgets[counter]
    
    
    # Calculate the average change in profits and losses (logical process)
    
    if counter < 1:
        counter += 1
        
    else:
        change_in_profits = budgets[counter] - budgets[counter - 1]
        total_change_in_profits_for_the_period =+ change_in_profits
        
        
        # if the profits in the previous month are less then the next month, then this condition has to be true:
        if change_in_profits >= 0:
            
            # If the current greatest increase in profits is less then what I calculate next...then that value,
            # will be replaced by the: change in profits:
            if change_in_profits > greatest_increase_in_profits:
                
                greatest_increase_in_profits = change_in_profits
                greatest_increase_in_profits_date = month_years[counter]
            
            # *****************************************MIGHT BE ABLE TO DELETE PART BELOW AND CHANGE >= TO JUST =0     
        else:
            if change_in_profits < greatest_decrease_in_losses:
                
                greatest_decrease_in_losses = change_in_profits
                gratest_decrease_in_losses_date = month_years[counter]
            
        counter += 1
        
# Avereage change in profit and round to the nearest 2nd decimal
average_change_in_profit = round(total_change_in_profits_for_the_period / (number_of_months - 1), 2)


# Print metric names

print("Financial Analysis")
print("...........................................................")
print(f"Total Months: {total_months}")
print(f"Average Change: $ {average_profit_change:,}")
print(f"Greatest Increase in Profits: {greatest_profit_increase} (${greatest_increase_in_profits: ,})")
print(f"Greatest Decrease in Profits: {greatest_decrease_in_profit} (${greatest_decrease_in_profit:} ,)")
