# %%
# Read in budget data from CSV file to form a list:

from pathlib import Path
import csv

# Set the csv file path:

csvpath = Path('../PyBank/budget_data.csv')

# Initialize the variables:

records = []

date = []

budgets = []

month_years = []

# Initialize line number

line_number = 0

# Open the input path as a file object:

with open (csvpath, 'r') as csvfile:
    
    # print the data type of the file object:
    
    print(type(csvfile))
    
    # Pass in the csv file to the csv.reader() function
    # (with ',' as the delmiter/separator) and return the csvreader object:

    csvreader = csv.reader(csvfile, delimiter =',')
    print(csvreader)
    
    # Print the datatype of the csvreader
    
    print(type(csvreader))
    
    # Go to the next row from the start of the file
    # (which is often the first row/header) and iterate line_num by 1
    header = next(csvreader)
    line_num += 1
    # Print the header
    print(f"{header} <---- HEADER")
    
    # Read each row of data after the header
    for row in csvreader:
        # Print the row
        print(row)
        
        # Set the salary variable for each row
        month_year = str(row[0])
        
        # Set the budget variable for each row
        budget = int(row[1])
        
        # Append the date value
        month_years.append(month_year)
        
        # Append the budget value
        budgets.append(budget)
        
        
    # Initialize the metric variables:
    
    total_months = 0
    
    net_profit_loss = 0
    
    change_in_profit = 0
    
    total_profit_change = 0
    
    average_profit_change = 0
    
    greatest_profit_increase = 0
    
    greatest_decrease_in_profit = 0
    
    greatest_profit_increase_date = 0
    
    greatest_decrease_in_profit_date = 0
    
    
    # Calculate all of the variables above:
    
counter = 0

while counter < len(budgets):
    
    
    # Add up all of the months
    
    number_of_months =+ 1
    
    # Add up the total profits and losses
    
    net_profit_losses =+ budgets[counter]
    
    # Average change in profit and loss - logic process
    
    if counter < 1:
        counter += 1
        
    else:
        change_in_profits = budgets[counter] - budgets[counter - 1]
        total_profit_change =+ change_in_profit
        if change_in_profit >= 0:
            if change_in_profit > greatest_profit_increase:
            greatest_profit_increase = change_in_profit
            greatest_profit_increase = month_years[counter]
            
    else:
        if change_in_profit < greatest_decrease_in_profit:
            greatest_decrease_in_profit = change_in_profit
            gratest_decrease_in_profit = month_years[counter]
            
        counter += 1
        
# Avereage change in profit and round to the nearest 2nd decimal
average_change_in_profit = round(total_profit_change / (total_months - 1), 2)


# Print metric names

print("Financial Analysis")
print("...........................................................")
print(f"Total Months: {total_months}")
print(f"Average Change: $ {average_profit_change:,}")
print(f"Greatest Increase in Profits: {greatest_profit_increase} (${greatest_increase_in_profits: ,})")
print(f"Greatest Decrease in Profits: {greatest_decrease_in_profit} (${greatest_decrease_in_profit:} ,})")
